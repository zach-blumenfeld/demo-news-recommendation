# %% [markdown]
# # Collaborative Filtering Example

# %%
from neo4j import GraphDatabase
import pandas as pd
import textwrap
import configparser
import os
pd.set_option('display.width', 0)
pd.set_option('display.max_colwidth', 500)

# %%
## Using an ini file for credentials, otherwise providing defaults
HOST = 'neo4j://localhost'
DATABASE = 'neo4j'
PASSWORD = 'password'
credential_properties = '/Users/zachblumenfeld/devtools/aura-news-demo.ini'
if os.path.exists(credential_properties):
    config = configparser.RawConfigParser()
    config.read(credential_properties)
    HOST = config['NEO4J']['HOST']
    DATABASE = config['NEO4J']['DATABASE']
    PASSWORD = config['NEO4J']['PASSWORD']
    print('Using custom database properties')
else:
    print('Could not find database properties file, using defaults')
# Out:
# Using custom database properties

# %%
# helper functions
def run(driver, query, params=None):
    with driver.session() as session:
        if params is not None:
            return [r for r in session.run(query, params)]
        else:
            return [r for r in session.run(query)]

def clear_graph(driver, graph_name):
    if run(driver, f"CALL gds.graph.exists('{graph_name}') YIELD exists RETURN exists")[0].get("exists"):
        run(driver, f"CALL gds.graph.drop('{graph_name}')")

def clear_model(driver, model_name):
    if run(driver, f"CALL gds.beta.model.exists('{model_name}') YIELD exists RETURN exists")[0].get("exists"):
        run(driver, f"CALL gds.beta.model.drop('{model_name}')")

# %%
driver = GraphDatabase.driver(HOST, auth=(DATABASE, PASSWORD))

# %% [markdown]
# ## Labeling Recent News
# News tends to be most relevant when it is recent and can lose relevance quickly with the passing of time.
# As such, the date the news is published is important to consider for recommendation.
#
# Unfortunately in this case, we do not have exact publish dates. To approximate, I used the minimum impression time.
# This means that news with NULL approximate times only showed up for historic clicks by users and were not included in
# any impressions inside our sample.
#
# For our Collaborative Filtering, we will only be interested in recommending recent content, so we will add a
# 'RecentNews' label to allow us to easily filter the graph in cypher queries and native projection. Remember that Neo4j
# allows a node to have multiple labels, so the original 'News label will still be retained.

# %%
run(driver, textwrap.dedent("""\
    MATCH(n:News) WHERE n.approxTime IS NOT NULL
    SET n:RecentNews
    RETURN count(n)
    """)
)
# Out:
# [<Record count(n)=22771>]

# %% [markdown]
# ## Basic Recommendation with Cypher
# From here we could try just using Cypher to accomplish Collaborative Filtering.  For example, we can do a three hop
# query to find potential recommendations for a given user based on the news clicked by users that viewed some of the same
# news they did.

# %%
result = run(driver, textwrap.dedent("""\
    MATCH (u1:User {userId: "U91836"})
           -[r1:CLICKED]->(n1:RecentNews)
           <-[r2:CLICKED]-(u2:User)
           -[r3:CLICKED]->(n2:RecentNews)
    RETURN count(DISTINCT n1) AS clickedNews,
           count(DISTINCT u2) AS likeUsers,
           count(DISTINCT n2) AS potentialRecommendations
    """)
)

pd.DataFrame([dict(record) for record in result])
# Out:
#    clickedNews  likeUsers  potentialRecommendations
# 0           11       3512                      4111

# %% [markdown]
# ## Scaling with FastRP Embeddings and K-Nearest-Neighbor (KNN)
#
# While the above can work well in some cases, and while it can certainly be a massive improvement from joining SQL tables or cross-walking over document stores, notice that we get a lot of results back (over 4k), and this is just a small sub-sample of the complete Microsoft dataset.
#
# For a production use case where recommendations will need to be queried frequently, this method will have trouble
# scaling as the graph grows.  We need some other strategy to help narrow down the results.
#
# One way to do this is with embeddings. Specifically, we can use FastRP to reduce the dimensionality of the problem then
# use an unsupervised ML technique called K-Nearest Neighbor (KNN) to identify, and draw recommendation relationships
# between, news with similar/close embeddings. Because the FastRP embeddings are based off the graph
# structure, news with similar embeddings should also be relatively connected in the graph via being clicked on by the
# same and similar users.

# %% [markdown]
# ### Graph Projection
# We will start with a graph projection leveraging just the User and RecentNews nodes.  We will include both historic and
# recent impression clicks, but we will give less weight to historic clicks so-as to favor more recent user activity.
#
# We will use an `UNDIRECTED` orientation so FastRP can traverse the graph bi-directionaly.

# %%
clear_graph(driver, 'cf-projection')
run(driver, textwrap.dedent("""\
    CALL gds.graph.create(
        'cf-projection',
        ['User', 'RecentNews'],
        {
            CLICKED:{
                orientation:'UNDIRECTED',
                properties: {weight: {property: 'weight', defaultValue: 1.0}}
            },
            HISTORICALLY_CLICKED:{
                orientation:'UNDIRECTED',
                properties: {weight: {property: 'weight', defaultValue: 0.2}}
            }
        }
    ) YIELD nodeCount, relationshipCount, createMillis""")
)
# Out:
# [<Record nodeCount=116828 relationshipCount=1250672 createMillis=239>]

# %% [markdown]
# ### FastRP
# When running FastRP we will make sure to include the relationship weight property

# %%
run(driver, textwrap.dedent("""\
    CALL gds.fastRP.mutate(
        'cf-projection',
        {
            mutateProperty: 'embedding',
            embeddingDimension: 196,
            randomSeed: 7474,
            relationshipWeightProperty: 'weight'
        }
    ) YIELD nodePropertiesWritten, computeMillis""")
)
# Out:
# [<Record nodePropertiesWritten=116828 computeMillis=1246>]

# %% [markdown]
# ### K-Nearest-Neighbor (KNN)
# We can then run KNN and write similarity (a.k.a. `USERS_ALSO_LIKED`) relationships back to the graph

# %%
result = run(driver, textwrap.dedent("""\
    CALL gds.beta.knn.write('cf-projection', {
        nodeLabels: ['RecentNews'],
        nodeWeightProperty: 'embedding',
        writeRelationshipType: 'USERS_ALSO_LIKED',
        writeProperty: 'score'
    }) YIELD *""")
)
pd.DataFrame([dict(record) for record in result])
# Out:
#    createMillis  computeMillis  writeMillis  postProcessingMillis  \
# 0             0           7798         4409                    -1
#
#    nodesCompared  relationshipsWritten  \
# 0          22771                227710
#
#                                                                                                                                                                                                                                                                                similarityDistribution  \
# 0  {'p1': 0.0, 'max': 1.000007152557373, 'p5': 0.0, 'p90': 0.48069334030151367, 'p50': 0.0, 'p95': 0.5845332145690918, 'p10': 0.0, 'p75': 0.3537726402282715, 'p99': 0.7942309379577637, 'p25': 0.0, 'p100': 1.000007152557373, 'min': 0.0, 'mean': 0.1761598638488499, 'stdDev': 0.2251492896885192}
#
#                                                                                                                                                                                                                                                                                                                                                               configuration
# 0  {'topK': 10, 'maxIterations': 100, 'writeConcurrency': 4, 'randomJoins': 10, 'perturbationRate': 0.0, 'sampleRate': 0.5, 'concurrency': 4, 'writeProperty': 'score', 'writeRelationshipType': 'USERS_ALSO_LIKED', 'nodeWeightProperty': 'embedding', 'nodeLabels': ['RecentNews'], 'sudo': False, 'relationshipTypes': ['*'], 'deltaThreshold': 0.001, 'username': None}

# %% [markdown]
# ### Collaborative Filtering Query with USER_ALSO_LIKED Relationships
# Now we can structure a similar Collaborative filtering query but with
# 1. more refined results,
# 2. using less traversal steps, and
# 3. with a score from KNN that allows us to rank order the results based on aggregate similarity

# %%
result = run(driver, textwrap.dedent("""\
    MATCH(u:User {userId: "U91836"})-[:CLICKED|HISTORICALLY_CLICKED]->(n:RecentNews)
    WITH collect(id(n)) AS clickedNewsIds

    //get similar News according to KNN and exclude previously clicked news
    MATCH (clickedNews)-[s:USERS_ALSO_LIKED]->(similarNews:News)
        WHERE id(clickedNews) IN clickedNewsIds AND NOT id(similarNews) IN clickedNewsIds

    //aggregate and return ranked results
    RETURN DISTINCT similarNews.newsId as newsId, similarNews.title AS title, similarNews.approxTime AS time,
        sum(s.score) AS totalScore ORDER BY totalScore DESC""")
)
pd.DataFrame([dict(record) for record in result])
# Out:
#      newsId  \
# 0    N54655
# 1     N2678
# 2    N12174
# 3    N50215
# 4    N50135
# ..      ...
# 129   N5454
# 130   N3182
# 131  N56479
# 132  N32753
# 133  N37377
#
#                                                                                                                  title  \
# 0        Peter Luger's says its steaks are still 'the best you can eat' after zero-star review from the New York Times
# 1    'The bridge has definitely been burned': Williams says Redskins have smeared him in aftermath of cancer diagnosis
# 2                     McCandless Police Looking To Identify 3 Women Credited With Giving Life-Saving CPR At North Park
# 3                        Icy conditions lead to multiple crashes on Pittsburgh bridges and throughout Allegheny County
# 4                                                          Nike will look into runner Mary Cain's allegations of abuse
# ..                                                                                                                 ...
# 129                                                  Veteran JPSO deputy arrested for payroll fraud in overtime scheme
# 130                          Brightline will be called Virgin Trains USA. So when will you see the new name on trains?
# 131                                                               Washington Judge Rules Value Village Misled Shoppers
# 132                                                eBay Find: Actual 'I Am Legend' 2007 Mustang Shelby GT500 Movie Car
# 133                                I Was A Psychic Phone Line Operator. Here's What Really Happened Behind The Scenes.
#
#                                     time  totalScore
# 0    2019-11-14T06:30:58.000000000+00:00    1.446628
# 1    2019-11-09T00:00:19.000000000+00:00    1.427643
# 2    2019-11-12T16:33:27.000000000+00:00    1.286185
# 3    2019-11-12T14:23:18.000000000+00:00    1.286185
# 4    2019-11-09T00:00:19.000000000+00:00    1.179345
# ..                                   ...         ...
# 129  2019-11-14T19:26:21.000000000+00:00    0.189312
# 130  2019-11-12T08:18:05.000000000+00:00    0.185018
# 131  2019-11-09T00:03:28.000000000+00:00    0.179169
# 132  2019-11-09T00:24:15.000000000+00:00    0.177132
# 133  2019-11-09T00:00:19.000000000+00:00    0.170380
#
# [134 rows x 4 columns]

# %% [markdown]
# And of course one can also add filters for score thresholds like so

# %%
result = run(driver, textwrap.dedent("""\
    MATCH(u:User {userId: "U91836"})-[:CLICKED|HISTORICALLY_CLICKED]->(n:RecentNews)
    WITH collect(id(n)) AS clickedNewsIds

    //get similar News according to KNN and exclude previously clicked news
    MATCH (clickedNews)-[s:USERS_ALSO_LIKED]->(similarNews:News)
        WHERE id(clickedNews) IN clickedNewsIds AND NOT id(similarNews) IN clickedNewsIds

    //aggregate and return ranked results
    WITH DISTINCT similarNews.newsId as newsId, similarNews.title AS title, similarNews.approxTime AS time,
        sum(s.score) AS totalScore
    WHERE totalScore >= $threshold RETURN * ORDER BY totalScore DESC"""), params = {'threshold':0.5}

)
pd.DataFrame([dict(record) for record in result])
# Out:
#     newsId                                 time  \
# 0   N54655  2019-11-14T06:30:58.000000000+00:00
# 1    N2678  2019-11-09T00:00:19.000000000+00:00
# 2   N12174  2019-11-12T16:33:27.000000000+00:00
# 3   N50215  2019-11-12T14:23:18.000000000+00:00
# 4   N50135  2019-11-09T00:00:19.000000000+00:00
# 5   N50451  2019-11-10T21:33:23.000000000+00:00
# 6   N64938  2019-11-12T13:07:06.000000000+00:00
# 7   N58153  2019-11-09T15:14:37.000000000+00:00
# 8    N8085  2019-11-09T16:59:14.000000000+00:00
# 9   N37889  2019-11-09T09:20:40.000000000+00:00
# 10  N24801  2019-11-10T13:43:06.000000000+00:00
# 11  N34287  2019-11-10T13:36:50.000000000+00:00
# 12  N29857  2019-11-09T00:31:29.000000000+00:00
# 13  N53037  2019-11-09T00:36:31.000000000+00:00
# 14  N31996  2019-11-09T07:00:52.000000000+00:00
# 15  N64536  2019-11-09T00:00:19.000000000+00:00
# 16   N1702  2019-11-09T00:36:31.000000000+00:00
# 17  N62959  2019-11-09T05:10:52.000000000+00:00
# 18  N58332  2019-11-14T06:30:58.000000000+00:00
# 19  N33373  2019-11-10T13:36:50.000000000+00:00
# 20  N13374  2019-11-09T07:00:52.000000000+00:00
# 21  N36946  2019-11-12T17:53:45.000000000+00:00
# 22  N55987  2019-11-10T14:49:22.000000000+00:00
# 23  N54168  2019-11-09T08:28:01.000000000+00:00
# 24    N995  2019-11-12T14:37:59.000000000+00:00
# 25  N30448  2019-11-09T10:17:27.000000000+00:00
# 26  N38276  2019-11-10T18:16:18.000000000+00:00
# 27  N61880  2019-11-09T00:00:19.000000000+00:00
# 28  N64242  2019-11-09T16:30:38.000000000+00:00
# 29  N10808  2019-11-10T16:16:02.000000000+00:00
# 30   N2670  2019-11-13T16:03:21.000000000+00:00
# 31  N34239  2019-11-12T14:50:17.000000000+00:00
# 32  N65034  2019-11-12T13:28:37.000000000+00:00
# 33  N16752  2019-11-12T15:11:53.000000000+00:00
# 34  N41485  2019-11-09T05:15:28.000000000+00:00
# 35  N58009  2019-11-09T03:56:00.000000000+00:00
# 36  N14830  2019-11-09T01:04:48.000000000+00:00
# 37    N670  2019-11-13T13:12:24.000000000+00:00
# 38  N55447  2019-11-12T17:15:15.000000000+00:00
# 39  N22364  2019-11-12T16:18:02.000000000+00:00
# 40  N38157  2019-11-11T12:53:42.000000000+00:00
# 41  N13834  2019-11-14T11:45:49.000000000+00:00
# 42  N10869  2019-11-11T18:32:44.000000000+00:00
# 43   N9523  2019-11-10T12:16:46.000000000+00:00
# 44  N57919  2019-11-14T16:29:32.000000000+00:00
# 45  N14911  2019-11-09T04:40:25.000000000+00:00
# 46  N20283  2019-11-12T10:23:27.000000000+00:00
# 47  N32608  2019-11-13T03:38:28.000000000+00:00
#
#                                                                                                                                            title  \
# 0                                  Peter Luger's says its steaks are still 'the best you can eat' after zero-star review from the New York Times
# 1                              'The bridge has definitely been burned': Williams says Redskins have smeared him in aftermath of cancer diagnosis
# 2                                               McCandless Police Looking To Identify 3 Women Credited With Giving Life-Saving CPR At North Park
# 3                                                  Icy conditions lead to multiple crashes on Pittsburgh bridges and throughout Allegheny County
# 4                                                                                    Nike will look into runner Mary Cain's allegations of abuse
# 5                                                                                            Police: Man killed in crash, fire in Pleasant Ridge
# 6                                                                                       Operation Hallowed Streets Checks On 5,000 Sex Predators
# 7                                                                                      Standing-room only tickets will go on sale day of MLS Cup
# 8                                                               Muskegon passes Cedar Springs district test in a rout; East Grand Rapids up next
# 9                                                  Florida man demands deputies take down his mug shot. They replaced it with his booking photo.
# 10                                                                                            NOPD investigating double shooting in Michoud area
# 11  A wellness influencer told her Instagram followers that shampoo causes weight gain, but nutrition experts are calling her comments 'madness'
# 12                                                                              Chrissy Teigen Apologizes for Her 'Tone Deaf' Joke About Her Mom
# 13                                      'We're standing by it': Sheriff doubles down on 'In God We Trust' decals after atheist group's complaint
# 14                                           Bill Gates: I'm happy to pay $20 billion in taxes, but Warren's plan would make me do a little math
# 15                                                                                                   Lil Pump bit by snake on set of music video
# 16                                                         James Brolin On the Hollywood Advice He Gave Son Josh: 'Don't Be a Leading Man, Ever'
# 17                                                                Nike hit with another damning op-ed: 'I was emotionally and physically abused'
# 18                                                       From cat names to fruit, here are 11 bizarre things celebrities have tried to trademark
# 19                                                                            Self-sufficient island hideouts for sale to survive the apocalypse
# 20                                                                             Fact Checker: Trump's shiny new talking point about income growth
# 21                                                                                       Greta Thunberg bound for Europe as new adventures await
# 22                                                                                                      What it's really like to retire in an RV
# 23                                                                                         Climate politics are tearing the West apart (opinion)
# 24                                                                                          10 of the best fast-food burger chains across the US
# 25                                                                             Toyota Dealer in Alabama Selling Slightly Used Supra for $167,000
# 26                                                           A family was brutally killed in Mexico, but sending U.S. troops to fight won't help
# 27                                                Dean Martin's Daughter Speaks Out About John Legend's New Version of 'Baby, It's Cold Outside'
# 28                                                                     Controversy follows NASCAR to Phoenix after Bubba Wallace Jr.'s admission
# 29                                                                                                                Evening news briefing from CNN
# 30                                                       Nina Mason Pulliam trust donates nearly $600,000 to protect water supply in Verde River
# 31                                                                                   Record low temperature possible Wednesday morning in Austin
# 32                                                            Northrop Grumman showcases new 2,500-employee missile-defense facility in Chandler
# 33                                                                            High Waves Reach Roofs, Threaten Homes On Lakefront In Rogers Park
# 34                                                                                                             The 20 best games of our lifetime
# 35                                                              I drank apple cider vinegar every morning for a month, and this is what happened
# 36                                                                                   Judge with breast cancer accused of misusing campaign money
# 37                                                                                              Your ultimate guide to holiday gifting etiquette
# 38                                                                   Cincinnati football moves up to No. 17 in College Football Playoff rankings
# 39                                                        13% of Americans say they know someone who died after they couldn't afford health care
# 40                                                                       Zachary Winston's death 'devastating,' says U-D Jesuit basketball coach
# 41                                                                                   National Guard GED participants make it to Ravens Honor Row
# 42                                                                                   Cummings' widow running for 7th District congressional seat
# 43                                                                                         'Hidden figures' to receive Congressional Gold Medals
# 44                                                                                   UD president says Arcade to get students out of 'UD bubble'
# 45                                                                                            6 matchups that matter in Cardinals vs. Buccaneers
# 46                                                                                Cold front had Kansas City residents sniffing Minnesota stench
# 47                                                                                  Fort Bragg team dispatched to N Carolina Interstate 26 crash
#
#     totalScore
# 0     1.446628
# 1     1.427643
# 2     1.286185
# 3     1.286185
# 4     1.179345
# 5     0.857061
# 6     0.792616
# 7     0.787982
# 8     0.758322
# 9     0.756572
# 10    0.751940
# 11    0.747339
# 12    0.744503
# 13    0.742634
# 14    0.737058
# 15    0.736627
# 16    0.731746
# 17    0.729538
# 18    0.726424
# 19    0.725892
# 20    0.717575
# 21    0.716173
# 22    0.714213
# 23    0.713365
# 24    0.712658
# 25    0.712362
# 26    0.711994
# 27    0.707189
# 28    0.703216
# 29    0.703216
# 30    0.691432
# 31    0.690989
# 32    0.664635
# 33    0.662753
# 34    0.636738
# 35    0.630548
# 36    0.567001
# 37    0.559277
# 38    0.542990
# 39    0.534621
# 40    0.534275
# 41    0.531517
# 42    0.531517
# 43    0.527862
# 44    0.521474
# 45    0.514872
# 46    0.513417
# 47    0.511646

# %% [markdown]
# This is a just another example for how, with GDS, we can leverage powerful graph analytics with only a few simple steps
# to scale a real-world use case.

# %% [markdown]
# and always remember to clean up and close your driver connections! :)

# %%
run(driver,'MATCH (n:RecentNews) REMOVE n:RecentNews')
run(driver,'MATCH ()-[r:USERS_ALSO_LIKED]->() DELETE r')
run(driver,'CALL gds.graph.drop("cf-projection")')
driver.close()
